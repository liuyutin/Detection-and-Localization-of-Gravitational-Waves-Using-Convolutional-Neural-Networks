# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
 
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
 
# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

u1 = np.linspace(1.300054, 1.400054, 100)
v1 = np.linspace(89.37228, 90.37228, 100)


x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

x1 = 10 * np.outer(np.cos(u1), np.sin(v1))
y1 = 10 * np.outer(np.sin(u1), np.sin(v1))
z1 = 10 * np.outer(np.ones(np.size(u1)), np.cos(v1))

# Plot the surface
ax.plot_surface(x1, y1, z1, color='r')
ax.plot_surface(x, y, z, color='b',alpha=0.1)
plt.show()

# %%
'''椭球面'''
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

fig = plt.figure(figsize=(20,16))
ax = fig.add_subplot(111, projection='3d')

# Make data
a,b,c= 5.0,25.0,7.0
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = a * np.outer(np.cos(u), np.sin(v))
y = b * np.outer(np.sin(u), np.sin(v))
z = c * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, color='orange', alpha = 0.5)

ax.grid()
ax.set_xlabel('X')
ax.set_xlim(-a, a)
ax.set_ylabel('Y')
ax.set_ylim(-b, b)
ax.set_zlabel('Z')
ax.set_zlim(-c, c)

plt.show()

# %%
import skymap
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-12-2f4db147eb5d> in <module>()
# ----> 1 import skymap
#
# ImportError: No module named skymap
